# %%
plc="https://www.tripadvisor.in/Hotels-g608471-Alappuzha_Alappuzha_District_Kerala-Hotels.html https://www.tripadvisor.in/Hotels-g303881-Munnar_Idukki_District_Kerala-Hotels.html"
urls=[]
urls=list(plc.split(" "))
urls
# https://www.tripadvisor.in/SmartDeals-g297636-Thekkady_Idukki_District_Kerala-Hotel-Deals.html
# Out:
# ['https://www.tripadvisor.in/Hotels-g608471-Alappuzha_Alappuzha_District_Kerala-Hotels.html',
#  'https://www.tripadvisor.in/Hotels-g303881-Munnar_Idukki_District_Kerala-Hotels.html']

# %%
import pandas as pd
df_hotel_urls=pd.DataFrame(columns=['Hotel Links'])
# urls=["https://www.tripadvisor.in/Hotels-g303881-Munnar_Idukki_District_Kerala-Hotels.html"]

# %%
df_hotel_urls
# Out:
# Empty DataFrame
# Columns: [Hotel Links]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests
for i in urls:
    r=requests.get(i)

    r

    c=r.content
    len(c)

    s=BeautifulSoup(c,"html.parser")
    len(s)

    name=s.find_all("div",{"class":"listing_title"})

    print(len(name),name[0].find('a').get('href'))

    minimum=min(len(name),20)
    minimum

    #putting all links in a list. Then list is inserted into dataframe
    list_urls=[]
    for i in range(0,minimum):
        list_urls.append("https://www.tripadvisor.in"+name[i].find('a').get('href'))



    import pandas as pd

#     df_hotel_urls=pd.DataFrame(list_urls,columns=['Hotel Links'])
    for i in list_urls:
        df_hotel_urls = df_hotel_urls.append({'Hotel Links':i}, ignore_index=True)


# df_hotel_urls
# Out:
# 30 /Hotel_Review-g608471-d12130064-Reviews-Lake_Canopy-Alappuzha_Alappuzha_District_Kerala.html
# 30 /Hotel_Review-g8342248-d10390860-Reviews-Parakkat_Nature_Hotels_Resorts-Pallivasal_Munnar_Idukki_District_Kerala.html

# %%
import time

# %%
list_urls[13]
# Out:
# 'https://www.tripadvisor.in/Hotel_Review-g10670898-d2276337-Reviews-Summit_Birds_Valley_Resort_Spa-Kunjithanny_Munnar_Idukki_District_Kerala.html'

# %%
len(df_hotel_urls)
# Out:
# 40

# %%
df_hotel_urls
# Out:
#                                           Hotel Links
# 0   https://www.tripadvisor.in/Hotel_Review-g60847...
# 1   https://www.tripadvisor.in/Hotel_Review-g60847...
# 2   https://www.tripadvisor.in/Hotel_Review-g60847...
# 3   https://www.tripadvisor.in/Hotel_Review-g60847...
# 4   https://www.tripadvisor.in/Hotel_Review-g60847...
# 5   https://www.tripadvisor.in/Hotel_Review-g60847...
# 6   https://www.tripadvisor.in/Hotel_Review-g60847...
# 7   https://www.tripadvisor.in/Hotel_Review-g60847...
# 8   https://www.tripadvisor.in/Hotel_Review-g60847...
# 9   https://www.tripadvisor.in/Hotel_Review-g60847...
# 10  https://www.tripadvisor.in/Hotel_Review-g60847...
# 11  https://www.tripadvisor.in/Hotel_Review-g60847...
# 12  https://www.tripadvisor.in/Hotel_Review-g60847...
# 13  https://www.tripadvisor.in/Hotel_Review-g60847...
# 14  https://www.tripadvisor.in/Hotel_Review-g60847...
# 15  https://www.tripadvisor.in/Hotel_Review-g60847...
# 16  https://www.tripadvisor.in/Hotel_Review-g60847...
# 17  https://www.tripadvisor.in/Hotel_Review-g60847...
# 18  https://www.tripadvisor.in/Hotel_Review-g60847...
# 19  https://www.tripadvisor.in/Hotel_Review-g60847...
# 20  https://www.tripadvisor.in/Hotel_Review-g83422...
# 21  https://www.tripadvisor.in/Hotel_Review-g83422...
# 22  https://www.tripadvisor.in/Hotel_Review-g30388...
# 23  https://www.tripadvisor.in/Hotel_Review-g52589...
# 24  https://www.tripadvisor.in/Hotel_Review-g52589...
# 25  https://www.tripadvisor.in/Hotel_Review-g52589...
# 26  https://www.tripadvisor.in/Hotel_Review-g30388...
# 27  https://www.tripadvisor.in/Hotel_Review-g10517...
# 28  https://www.tripadvisor.in/Hotel_Review-g10517...
# 29  https://www.tripadvisor.in/Hotel_Review-g83422...
# 30  https://www.tripadvisor.in/Hotel_Review-g10517...
# 31  https://www.tripadvisor.in/Hotel_Review-g30388...
# 32  https://www.tripadvisor.in/Hotel_Review-g30388...
# 33  https://www.tripadvisor.in/Hotel_Review-g10670...
# 34  https://www.tripadvisor.in/Hotel_Review-g83422...
# 35  https://www.tripadvisor.in/Hotel_Review-g52589...
# 36  https://www.tripadvisor.in/Hotel_Review-g30388...
# 37  https://www.tripadvisor.in/Hotel_Review-g96837...
# 38  https://www.tripadvisor.in/Hotel_Review-g96837...
# 39  https://www.tripadvisor.in/Hotel_Review-g30388...

# %%
import pandas as pd
df_each_hotel=pd.DataFrame(columns=['Hotel Names','Price','Rating','Amenities','Info','Attractions','Address','City'])

# %%
for i in range(len(df_hotel_urls)) : 
    link=df_hotel_urls.iloc[i, 0]
    r=requests.get(link)
    
    c=r.content
    s=BeautifulSoup(c,"html.parser")
    
    dictionary_details={}
    
    #City
    try:
        list_place=[]
        place=s.find_all("span",{"class":"hotels-hotel-review-about-with-photos-PopIndex__popIndex--zNSxv"})
        list_place=list(place[0].text.split(" "))
        dictionary_details['City']=list_place[-1]#last one is always place name
    except:
        dictionary_details['City']=float('Nan')
        

    #Hotel Name
    name=s.find_all("h1")
    dictionary_details['Hotel Names']=name[1].text

    #Price
    try:
        price=s.find_all("div" ,{"class":"hotels-hotel-offers-DominantOffer__price--D-ycN"})
        dictionary_details['Price']=price[0].text[2:]
    except:
        try:
            
            price=s.find_all("div" ,{"class":"hotels-hotel-offers-DetailChevronOffer__price--py2LH"})
            dictionary_details['Price']=price[0].text[2:]
        except:
            dictionary_details['Price']=float('Nan')
    
    #Ratinf
    try:
        rating=s.find_all("span" ,{"class":"hotels-hotel-review-about-with-photos-Reviews__overallRating--vElGA"})
        dictionary_details['Rating']=rating[0].text
    except:
        dictionary_details['Rating']=float("Nan")
        
    #Aminitis
    try:
        amenities=s.find_all("div" ,{"class":"hotels-hr-about-amenities-AmenityGroup__amenitiesList--3MdFn"})
        dictionary_details['Amenities']=amenities[0].text
    except:
        dictionary_details['Amenities']=float('Nan')
        
    #INfo
    try:
        info=s.find_all("div" ,{"class":"cPQsENeY"})
        dictionary_details['Info']=info[0].text
    except:
        dictionary_details['Info']=float('Nan')

    #Attractions
#     print(attractions_nearby[4:][0].text,",", attractions_nearby[4:][1].text,",",
#     attractions_nearby[4:][2].text,",", attractions_nearby[4:][3].text)
#     len(attractions_nearby[4:])
    try:
        attractions_nearby=s.find_all("div" ,{"class":"hotels-hotel-review-location-NearbyLocation__name--1pAvV"})
        Full_Attraction=""
        Full_Attraction=attractions_nearby[4:][0].text, attractions_nearby[4:][1].text,attractions_nearby[4:][2].text, attractions_nearby[4:][3].text
        dictionary_details['Attractions']=Full_Attraction
    
    except:
        dictionary_details['Attractions']=float('Nan')


    

    #add
    try:
        address=s.find_all("span" ,{"class":"public-business-listing-ContactInfo__ui_link--1_7Zp public-business-listing-ContactInfo__level_4--3JgmI"})
        dictionary_details['Address']=address[0].text
    except:
        dictionary_details['Address']=float('Nan')

    
    df_each_hotel=df_each_hotel.append(dictionary_details,ignore_index=True)
    
    time.sleep(1)

# %%
df_each_hotel
# Out:
#                                  Hotel Names   Price Rating  \
# 0                                Lake Canopy   6,528    5.0
# 1                         Lake Palace Resort     NaN    4.0
# 2                      Uday Backwater Resort   8,990    5.0
# 3                          Warmth Lake Haven   4,367    4.5
# 4                 Ramada by Wyndham Alleppey   3,238    4.0
# 5                    Oxygen Resorts Alleppey   3,480    5.0
# 6                         Kalappura Homestay     999    5.0
# 7                           Punnamada Resort   8,346    4.5
# 8           Treebo Tryst Palmyra Grand Suite   1,766    4.0
# 9                            Cosy Houseboats   5,451    4.5
# 10      Kondai Lip Backwater Heritage Resort   5,005    4.5
# 11                     Alleppey Beach Garden   4,704    5.0
# 12                         Abad Turtle Beach   8,473    4.5
# 13                             Venice Castle   1,680    5.0
# 14            Malayalam Lake Resort Homestay   2,072    4.5
# 15  Cyrus Resorts by Tolins Hotels & Resorts   4,447    4.0
# 16                Lake Castle Alleppey Villa   1,190    5.0
# 17                     Baywatch Beach Resort   1,020    4.5
# 18                  Coir Village Lake Resort   2,534    3.5
# 19                      The World Backwaters   4,656    4.0
# 20          Parakkat Nature Hotels & Resorts   5,052    5.0
# 21                       Blanket Hotel & Spa  11,543    5.0
# 22                              Elixir Hills   4,656    4.5
# 23                       Chandys Windy Woods     NaN    5.0
# 24                           The Leaf Munnar   5,625    5.0
# 25                 Munnar Tea Country Resort   6,169    4.5
# 26                          Dew Drops Munnar   1,714    4.5
# 27                         Tea Valley Resort   2,623    4.5
# 28                    Fragrant Nature Munnar   9,222    5.0
# 29   Amber Dale Luxury Hotel and Spa, Munnar   6,032    5.0
# 30                     The Tall Trees Munnar   5,902    4.5
# 31           Dream Catcher Plantation Resort   4,499    4.5
# 30  Bison Valley Road, Pothamedu, Munnar 685612 India      Pothamedu
# 31  Tea Company Bisonvalley Road Ratnagiri, Munnar...         Munnar
# 32  Mankulam Road, Near Letchmi Tea Estate, Munnar...         Munnar
# 33  Bison Valley Road, Kunjithanny, Munnar 685565 ...            NaN
# 34  Randam Mile or Second Mile Junction, Beside Ko...     Pallivasal
# 35  Chithirapuram Po Chithirapuram Near Pallivasal...  Chithirapuram
# 36                      MSA Road, Munnar 685612 India         Munnar
# 37  Chinnakanal Suryanelli Rd, Chinnakanal, Munnar...    Chinnakanal
# 38                   Chinnakanal, Munnar 685612 India    Chinnakanal
# 39  Near Recreation Club Pallivasal, Munnar 685151...         Munnar

# %%
df_each_hotel.to_csv('Travel_Rec1.csv',index=False, encoding = 'utf-8')

# %% [markdown]
# # Users dataset

# %%
df_users_data=pd.DataFrame(columns=["User Name","Profile link","Rating","Hotel Name"])
df_users_data
# Out:
# Empty DataFrame
# Columns: [User Name, Profile link, Rating, Hotel Name]
# Index: []

# %%
for i in range(len(df_hotel_urls)) : 
    link=df_hotel_urls.iloc[i, 0]
    r=requests.get(link)
    
    c=r.content
    s=BeautifulSoup(c,"html.parser")
    for i in range(0,5):
    #Name and link
        dictionary_details={}

        user_name=s.find_all("a",{"class":"ui_header_link social-member-event-MemberEventOnObjectBlock__member--35-jC"})
        review_user_name=user_name[i].text
        review_user_link="https://www.tripadvisor.in"+user_name[i].get("href") 
        dictionary_details["User Name"]=review_user_name
        dictionary_details["Profile link"]=review_user_link

        # user_rating[0]

        user_rating=s.find_all("div",{"class":"location-review-review-list-parts-RatingLine__bubbles--GcJvM"})
        rate=0
        x=user_rating[i]
        if x.find("span",{"class":"ui_bubble_rating bubble_50"}):
            rate=5
        elif x.find("span",{"class":"ui_bubble_rating bubble_40"}):
            rate=4
        elif x.find("span",{"class":"ui_bubble_rating bubble_30"}):
            rate=3
        elif x.find("span",{"class":"ui_bubble_rating bubble_20"}):
            rate=2
        elif x.find("span",{"class":"ui_bubble_rating bubble_10"}):
            rate=1

        dictionary_details["Rating"]=rate
        hotel_name=s.find_all("h1")
        dictionary_details['Hotel Name']=hotel_name[1].text
        df_users_data=df_users_data.append(dictionary_details,ignore_index=True)

# %%
df_users_data
# Out:
#                 User Name                                       Profile link  \
# 0                  Rachna        https://www.tripadvisor.in/Profile/Rachneer
# 1               Amey Naik     https://www.tripadvisor.in/Profile/AmeyNaik123
# 2            IanGBradford    https://www.tripadvisor.in/Profile/IanGBradford
# 3             lccarey2018     https://www.tripadvisor.in/Profile/lccarey2018
# 4                 Aamir R       https://www.tripadvisor.in/Profile/267aamirr
# 5               Kajalashu       https://www.tripadvisor.in/Profile/Kajalashu
# 6               _rarebird      https://www.tripadvisor.in/Profile/rarebird_1
# 7               maxsanjay        https://www.tripadvisor.in/Profile/sanjumax
# 8            Sagar Jadhav  https://www.tripadvisor.in/Profile/Sightsee394244
# 191       shivangi_sharma  https://www.tripadvisor.in/Profile/shivangi_sh...
# 192        Prakash Navhal    https://www.tripadvisor.in/Profile/Travel552167
# 193              Abelkutt        https://www.tripadvisor.in/Profile/Abelkutt
# 194           Salman Khan     https://www.tripadvisor.in/Profile/isalmankhan
# 195        Mahesh Reddy K  https://www.tripadvisor.in/Profile/maheshreddy...
# 196         Khawaza Ali S     https://www.tripadvisor.in/Profile/khawazaalis
# 197               Prakash     https://www.tripadvisor.in/Profile/prakashgbca
# 198             vignesh V     https://www.tripadvisor.in/Profile/803vigneshv
# 199             Madhurika       https://www.tripadvisor.in/Profile/madhu2210
#
#     Rating                    Hotel Name
# 0        3                   Lake Canopy
# 1        5                   Lake Canopy
# 2        5                   Lake Canopy
# 3        5                   Lake Canopy
# 4        5                   Lake Canopy
# 5        5            Lake Palace Resort
# 6        5            Lake Palace Resort
# 7        5            Lake Palace Resort
# 8        2            Lake Palace Resort
# 9        5            Lake Palace Resort
# 10       4         Uday Backwater Resort
# 11       5         Uday Backwater Resort
# 12       5         Uday Backwater Resort
# 13       5         Uday Backwater Resort
# 14       2         Uday Backwater Resort
# 15       3             Warmth Lake Haven
# 16       5             Warmth Lake Haven
# 17       5             Warmth Lake Haven
# 18       1             Warmth Lake Haven
# 19       1             Warmth Lake Haven
# 20       2    Ramada by Wyndham Alleppey
# 21       5    Ramada by Wyndham Alleppey
# 22       1    Ramada by Wyndham Alleppey
# 23       5    Ramada by Wyndham Alleppey
# 24       5    Ramada by Wyndham Alleppey
# 25       5       Oxygen Resorts Alleppey
# 26       5       Oxygen Resorts Alleppey
# 27       5       Oxygen Resorts Alleppey
# 28       5       Oxygen Resorts Alleppey
# 29       5       Oxygen Resorts Alleppey
# ..     ...                           ...
# 170      3  Misty Mountain Resort Munnar
# 171      5  Misty Mountain Resort Munnar
# 172      5  Misty Mountain Resort Munnar
# 173      3  Misty Mountain Resort Munnar
# 174      5  Misty Mountain Resort Munnar
# 175      5               Cuckmere Resort
# 176      5               Cuckmere Resort
# 177      5               Cuckmere Resort
# 178      5               Cuckmere Resort
# 179      5               Cuckmere Resort
# 180      5            Grand Plaza Munnar
# 181      4            Grand Plaza Munnar
# 182      5            Grand Plaza Munnar
# 183      4            Grand Plaza Munnar
# 184      5            Grand Plaza Munnar
# 185      5          Mountain Club Resort
# 186      4          Mountain Club Resort
# 187      5          Mountain Club Resort
# 188      5          Mountain Club Resort
# 189      5          Mountain Club Resort
# 190      3               Sterling Munnar
# 191      1               Sterling Munnar
# 192      4               Sterling Munnar
# 193      4               Sterling Munnar
# 194      5               Sterling Munnar
# 195      4              Glenmore Resorts
# 196      4              Glenmore Resorts
# 197      5              Glenmore Resorts
# 198      5              Glenmore Resorts
# 199      5              Glenmore Resorts
#
# [200 rows x 4 columns]

# %%
df_users_data.to_csv('UserData_Travel_Rec1.csv',index=False, encoding = 'utf-8')
